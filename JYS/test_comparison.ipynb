# %%
import numpy as np
import pandas as pd

test = pd.read_csv('test_result/full_leaderboard.csv')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Experiment_Name              84 non-null     object
#  1   Run_Time                     84 non-null     object
#  2   model                        84 non-null     object
#  3   score_val                    84 non-null     float64
#  4   eval_metric                  84 non-null     object
#  5   pred_time_val                84 non-null     float64
#  6   fit_time                     84 non-null     float64
#  7   pred_time_val_marginal       84 non-null     float64
#  8   fit_time_marginal            84 non-null     float64
#  9   stack_level                  84 non-null     int64
#  10  can_infer                    84 non-null     bool
#  11  fit_order                    84 non-null     int64
#  12  num_features                 84 non-null     int64
# ...

# %%
test.sort_values(by='score_val', ascending=False).drop_duplicates(subset=['model'])[['Experiment_Name','model', 'score_val', 'features']].head()
# Out:
#    Experiment_Name                model  score_val  \
# 30       no weight  WeightedEnsemble_L3   0.793804
# 55         no call    ExtraTrees_BAG_L2   0.790443
# 32       no weight  RandomForest_BAG_L2   0.786706
# 57         no call      CatBoost_BAG_L2   0.770871
# 58         no call      LightGBM_BAG_L2   0.768045
#
#                                              features
# 30  ['LightGBM_BAG_L2', 'ExtraTrees_BAG_L2', 'Rand...
# 55  ['Discount_Group', 'Prior_purchases', 'LinearM...
# 32  ['Discount_Group', 'Discount_rate', 'log_price...
# 57  ['Discount_Group', 'Prior_purchases', 'LinearM...
# 58  ['Discount_Group', 'Prior_purchases', 'LinearM...

# %%
col = ['child_hyperparameters', 'child_hyperparameters_fit', 'child_ag_args_fit', 'ancestors', 'descendants']

# %%
test.sort_values(by='score_val', ascending=False).drop_duplicates(subset=['model'])[col].head()
# Out:
#                                 child_hyperparameters  \
# 30   {'ensemble_size': 25, 'subsample_size': 1000000}
# 55  {'n_estimators': 300, 'max_leaf_nodes': 15000,...
# 32  {'n_estimators': 300, 'max_leaf_nodes': 15000,...
# 57  {'iterations': 10000, 'learning_rate': 0.05, '...
# 58                 {'learning_rate': 0.05, 'seed': 0}
#
#    child_hyperparameters_fit  \
# 30     {'ensemble_size': 24}
# 55     {'n_estimators': 300}
# 32     {'n_estimators': 300}
# 57       {'iterations': 206}
# 58  {'num_boost_round': 163}
#
#                                     child_ag_args_fit  \
# 30  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
# 55  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
# 32  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
# 57  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
# 58  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
#
#                                             ancestors              descendants
# ...
